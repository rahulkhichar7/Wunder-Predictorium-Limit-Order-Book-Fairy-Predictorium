# %%
import numpy as np 
import pandas as pd

# %%
PATH = r"wnn_predictorium_starterpack\competition_package\datasets\valid.parquet"
df = pd.read_parquet(PATH)
df.head()
# Out:
#    seq_ix  step_in_seq  need_prediction        p0        p1        p2  \
# 0       0            0                0  0.892038 -0.546700  0.293986
# 1       0            1                0  1.059682 -0.658043  0.404717
# 2       0            2                0  1.035790 -0.832006  0.330873
# 3       0            3                0  1.307063 -0.853480  0.504922
# 4       0            4                0  1.059682 -0.658043  0.404717
#
#          p3        p4        p5        p6  ...       dp0       dp1       dp2  \
# 0  0.728240  0.115678 -0.018820  1.803203  ... -0.030025  0.836811  0.336509
# 1  0.754664  0.076604 -0.077862  2.056872  ...  0.610484 -0.724973  0.522099
# 2  0.705530 -0.006273 -0.172731  2.065579  ...  0.084155 -0.445919  0.658043
# 3  0.773140  0.020074 -0.153660  2.279624  ...  0.598435 -1.004131  0.832006
# 4  0.754664  0.076604 -0.077862  1.739312  ...  0.288750 -0.046436  0.555462
#
#         dp3       dv0       dv1       dv2       dv3        t0        t1
# ...

# %%
df.to_csv("Sample.csv")
